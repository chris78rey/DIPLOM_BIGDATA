# %%
from operator import irshift
from sklearn.datasets import load_iris
from sklearn import tree
iris = load_iris()
X, y = iris.data, iris.target
'''tranformo X e y en dataframe'''
import pandas as pd
X = pd.DataFrame(X)
y = pd.DataFrame(y)

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
'''dibuje que se vea bien el arbol y completo quiero verlo muy grande que yo defina el tamaño'''

tree.plot_tree(clf, filled=True, fontsize=7, feature_names=iris.feature_names, class_names=iris.target_names, max_depth=2, impurity=False, proportion=True)
# Out:
# [Text(125.55000000000001, 190.26, 'petal width (cm) <= 0.8\nsamples = 100.0%\nvalue = [0.333, 0.333, 0.333]\nclass = setosa'),
#  Text(83.7, 135.9, 'samples = 33.3%\nvalue = [1.0, 0.0, 0.0]\nclass = setosa'),
#  Text(167.4, 135.9, 'petal width (cm) <= 1.75\nsamples = 66.7%\nvalue = [0.0, 0.5, 0.5]\nclass = versicolor'),
#  Text(83.7, 81.53999999999999, 'petal length (cm) <= 4.95\nsamples = 36.0%\nvalue = [0.0, 0.907, 0.093]\nclass = versicolor'),
#  Text(41.85, 27.180000000000007, '\n  (...)  \n'),
#  Text(125.55000000000001, 27.180000000000007, '\n  (...)  \n'),
#  Text(251.10000000000002, 81.53999999999999, 'petal length (cm) <= 4.85\nsamples = 30.7%\nvalue = [0.0, 0.022, 0.978]\nclass = virginica'),
#  Text(209.25, 27.180000000000007, '\n  (...)  \n'),
#  Text(292.95, 27.180000000000007, '\n  (...)  \n')]

# %%
import graphviz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_14548/61101935.py in <module>
# ----> 1 import graphviz
#
# ModuleNotFoundError: No module named 'graphviz'
