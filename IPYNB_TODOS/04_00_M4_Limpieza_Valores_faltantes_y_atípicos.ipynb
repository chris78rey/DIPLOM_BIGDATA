# %% [markdown]
# <img src = "https://github.com/HarryVargas96/UdeCataluna/blob/main/logo_uc_grande.png?raw=true" alt = "Encabezado" width = "100%">  </img>

# %% [markdown]
# # **Taller guiado de limpieza de valores faltantes y datos atípicos**

# %% [markdown]
# Este taller guiado tiene como objetivo hacer un acercamiento práctico a la limpieza y preparación de un conjunto de datos.
#
# En este taller guiado veremos como:
# * Corregir valores faltantes- eliminación o reemplazo
# * Detección de valores atípicos

# %% [markdown]
# ## **1. Instalar e importar los paquetes necesarios**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **2. Cargar datos**

# %% [markdown]
# Cargamos un dataset con 100.974 observaciones obtenido de un muestreo de los resultados del ICFES 2020 segundo periodo. Este es un subconjunto del dataset original donde se han escogido 14 variables de estudio. La variable V1 fue creada durante el procesamiento que permitió la creación del dataset. Cada observación pertenece a los datos de un estudiante, se puede encontrar información socioeconómica del estudiante y su familia. El objetivo de análisis principal de este dataset es identificar el impacto de las condiciones socieconómicoas sobre el desempeño general de la prueba `PUNT_GLOBAL`. El enfoque en este notebook es hacer el trabajo de limpieza del dataset, puede realizar la exploración por su cuenta.

# %%
icfes = pd.read_csv('https://raw.githubusercontent.com/HarryVargas96/ICFES/main/icfes_2020_reducido.csv')

# %%
icfes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100974 entries, 0 to 100973
# Data columns (total 15 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            100974 non-null  int64
#  1   ESTU_GENERO           100972 non-null  object
#  2   ESTU_FECHANACIMIENTO  100974 non-null  object
#  3   ESTU_TIENEETNIA       100363 non-null  object
#  4   ESTU_DEPTO_RESIDE     100974 non-null  object
#  5   FAMI_ESTRATOVIVIENDA  97576 non-null   object
#  6   FAMI_EDUCACIONPADRE   98373 non-null   object
#  7   FAMI_EDUCACIONMADRE   98267 non-null   object
#  8   FAMI_TIENEINTERNET    98274 non-null   object
#  9   FAMI_TIENECOMPUTADOR  96928 non-null   object
#  10  COLE_NATURALEZA       100974 non-null  object
#  11  COLE_AREA_UBICACION   100974 non-null  object
#  12  COLE_JORNADA          100974 non-null  object
#  13  PUNT_GLOBAL           100974 non-null  int64
#  14  ESTU_GENERACION-E     100974 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 11.6+ MB

# %% [markdown]
# A su vez también cargamos una serie de tiempo, estos datos provienen de un sensor ambiental ubicado en la ciudad de Londres. Corresponde a las mediciones de la concentración de material particulado PM2.5 es decir, diametro de 2.5 micras o menos durante el año de 2018 con una frecuencia de recolección de 15 minutos. Para más información del dataset consulte [aquí](https://www.londonair.org.uk/london/asp/datadownload.asp).

# %%
air = pd.read_csv('https://raw.githubusercontent.com/HarryVargas96/UdeCataluna/main/Londonair.csv')

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35040 entries, 0 to 35039
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Site                     35040 non-null  object
#  1   Species                  35040 non-null  object
#  2   ReadingDateTime          35040 non-null  object
#  3   Value                    32136 non-null  float64
#  4   Units                    35040 non-null  object
#  5   Provisional or Ratified  35040 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# ## **3. Dataset ICFES**

# %% [markdown]
# ### Conversión y transformación de variables
#
# Para facilitar el trabajo vamos a transformar las variables cualitativas que aparecen como character en factores, y vamos a eliminar la variable V1.

# %%
# Eliminación de variable, recuerde crear una copia si no está seguro de eliminar la variable de manera permanente
icfes_copy = icfes
icfes.drop(columns='Unnamed: 0',inplace=True)
icfes
# Out:
#        ESTU_GENERO ESTU_FECHANACIMIENTO ESTU_TIENEETNIA ESTU_DEPTO_RESIDE  \
# 0                M           27/04/2002              No      CUNDINAMARCA
# 1                M           19/05/2005              Si             VALLE
# 2                F           07/08/2002              Si            NARIÑO
# 3                M           03/10/2001              Si            BOGOTÁ
# 4                M           21/08/2002              No         ANTIOQUIA
# ...            ...                  ...             ...               ...
# 100969           M           01/10/2002              No            BOGOTÁ
# 100970           M           28/08/2003              Si        SAN ANDRES
# 100971           M           21/05/2003              No            BOGOTÁ
# 100972           F           15/03/2002              No         ATLANTICO
# 100973           F           29/05/2004              No              META
#
#        FAMI_ESTRATOVIVIENDA                 FAMI_EDUCACIONPADRE  \
# 0                 Estrato 3                             No sabe
# 1                 Estrato 2  Secundaria (Bachillerato) completa
# 2                 Estrato 1      Educación profesional completa
# 3                 Estrato 2                           Postgrado
# 4                 Estrato 2    Educación profesional incompleta
# ...                     ...                                 ...
# 100969            Estrato 2      Educación profesional completa
# 100970            Estrato 3  Secundaria (Bachillerato) completa
# 100971            Estrato 3                             No sabe
# 100972            Estrato 6  Secundaria (Bachillerato) completa
# 100973            Estrato 2  Secundaria (Bachillerato) completa
#
#                        FAMI_EDUCACIONMADRE FAMI_TIENEINTERNET  \
# 0                                  No sabe                 Si
# 1       Secundaria (Bachillerato) completa                 Si
# 2       Secundaria (Bachillerato) completa                 Si
# 3           Técnica o tecnológica completa                 Si
# 4                      Primaria incompleta                 Si
# ...                                    ...                ...
# 100969      Educación profesional completa                 Si
# 100970      Técnica o tecnológica completa                 Si
# 100971      Educación profesional completa                 Si
# 100972      Técnica o tecnológica completa                 Si
# 100973  Secundaria (Bachillerato) completa                 Si
#
#        FAMI_TIENECOMPUTADOR COLE_NATURALEZA COLE_AREA_UBICACION COLE_JORNADA  \
# 0                        Si         OFICIAL              URBANO       MAÑANA
# 1                        Si         OFICIAL              URBANO       MAÑANA
# 2                        No         OFICIAL              URBANO       MAÑANA
# 3                        Si         OFICIAL              URBANO       MAÑANA
# 4                        Si         OFICIAL              URBANO       MAÑANA
# ...                     ...             ...                 ...          ...
# 100969                   Si      NO OFICIAL              URBANO     COMPLETA
# 100970                   Si      NO OFICIAL              URBANO       MAÑANA
# 100971                   Si      NO OFICIAL              URBANO     COMPLETA
# 100972                   Si      NO OFICIAL              URBANO       MAÑANA
# 100973                   No         OFICIAL              URBANO       MAÑANA
#
#         PUNT_GLOBAL         ESTU_GENERACION-E
# 0               267                        NO
# 1               282                        NO
# 2               226  GENERACION E - GRATUIDAD
# 3               237                        NO
# 4               229                        NO
# ...             ...                       ...
# 100969          320                        NO
# 100970          263  GENERACION E - GRATUIDAD
# 100971          244                        NO
# 100972          215                        NO
# 100973          254                        NO
#
# [100974 rows x 14 columns]

# %% [markdown]
# La variable `ESTU_FECHANACIMIENTO` tal como está no sirve para el análisis, es necesario crear la variable `EDAD`.
#
#
# Para eso vamos a usar la libreria lubridate y una función nueva. Como queremos saber la edad de los estudiantes al momento de presentar la prueba debemos tener presente que la prueba se realizó el 9 de agosto de 2020.

# %%
from datetime import datetime
# Modulo que permite trabajar con fechas
# strptime es un método que permite convertir un string a fecha de acuerdo 
def edad(cadena):
    birth = datetime.strptime(cadena, '%d/%m/%Y') # Fecha nacimiento
    prueba = datetime.strptime('09/08/2020', '%d/%m/%Y') #Fecha presentación examen
    return prueba.year - birth.year # Edad el día de presentación del examen

edad('18/04/1996') # Celda de prueba
# Out:
# 24

# %%
edad('07/06/1996')
# Out:
# 24

# %%
datetime.strptime('07/06/1996', '%d/%m/%Y')
# Out:
# datetime.datetime(1996, 6, 7, 0, 0)

# %%
a = datetime.today().year-datetime.strptime('07/06/1996', '%d/%m/%Y').year

# %%
a
# Out:
# 26

# %%
x = datetime(2018, 6, 1)

# %%
x.month
# Out:
# 6

# %% [markdown]
# Para la transformación de los datos se utiliza una método de mapeo conocido como `apply`, lo que haremos será aplicar la función `edad` declarada anteriormente sobre todas las filas del dataset `icfes`.

# %%
icfes['ESTU_EDAD']  = icfes['ESTU_FECHANACIMIENTO'].apply( lambda x: edad(x) )

# %%
icfes.head()
# Out:
#   ESTU_GENERO ESTU_FECHANACIMIENTO ESTU_TIENEETNIA ESTU_DEPTO_RESIDE  \
# 0           M           27/04/2002              No      CUNDINAMARCA
# 1           M           19/05/2005              Si             VALLE
# 2           F           07/08/2002              Si            NARIÑO
# 3           M           03/10/2001              Si            BOGOTÁ
# 4           M           21/08/2002              No         ANTIOQUIA
#
#   FAMI_ESTRATOVIVIENDA                 FAMI_EDUCACIONPADRE  \
# 0            Estrato 3                             No sabe
# 1            Estrato 2  Secundaria (Bachillerato) completa
# 2            Estrato 1      Educación profesional completa
# 3            Estrato 2                           Postgrado
# 4            Estrato 2    Educación profesional incompleta
#
#                   FAMI_EDUCACIONMADRE FAMI_TIENEINTERNET FAMI_TIENECOMPUTADOR  \
# 0                             No sabe                 Si                   Si
# 1  Secundaria (Bachillerato) completa                 Si                   Si
# 2  Secundaria (Bachillerato) completa                 Si                   No
# 3      Técnica o tecnológica completa                 Si                   Si
# 4                 Primaria incompleta                 Si                   Si
#
#   COLE_NATURALEZA COLE_AREA_UBICACION COLE_JORNADA  PUNT_GLOBAL  \
# 0         OFICIAL              URBANO       MAÑANA          267
# 1         OFICIAL              URBANO       MAÑANA          282
# 2         OFICIAL              URBANO       MAÑANA          226
# 3         OFICIAL              URBANO       MAÑANA          237
# 4         OFICIAL              URBANO       MAÑANA          229
#
#           ESTU_GENERACION-E  ESTU_EDAD
# 0                        NO         18
# 1                        NO         15
# 2  GENERACION E - GRATUIDAD         18
# 3                        NO         19
# 4                        NO         18

# %% [markdown]
# ### Detección y corrección de datos atípicos

# %% [markdown]
# Hagamos una revisión e inspección visual de la variable `EDAD` usando un boxplot. Es bastante claro la presencia de valores atípicos, con una edad máxima de 2018.

# %%
icfes.describe()
# Out:
#          PUNT_GLOBAL      ESTU_EDAD
# count  100974.000000  100974.000000
# mean      248.445986      17.635966
# std        48.741511       9.357959
# min         0.000000       0.000000
# 25%       211.000000      17.000000
# 50%       245.000000      17.000000
# 75%       282.000000      18.000000
# max       500.000000    2018.000000

# %%
sns.boxplot(data=icfes, x='ESTU_EDAD')

# %%
plt.hist( icfes['ESTU_EDAD'])
plt.show();

# %% [markdown]
# Veamos los datos atípicos usando un filtro.

# %%
icfes.loc[icfes['ESTU_EDAD']> 80,['ESTU_EDAD','ESTU_FECHANACIMIENTO']]
# Out:
#        ESTU_EDAD ESTU_FECHANACIMIENTO
# 73036       2018           30/06/0002
# 80700       2017           07/04/0003
# 87761        120           01/01/1900

# %% [markdown]
# Al visualizar los datos con este filtro se observan 3 observaciones atípicas con edades de 120, 2017 y 2018 años. Al tratarse de errores en la recolección es necesario eliminar estas observaciones.

# %%
icfes2 = icfes.loc[icfes['ESTU_EDAD']<80]

icfes2.describe()
# Out:
#          PUNT_GLOBAL      ESTU_EDAD
# count  100971.000000  100971.000000
# mean      248.445019      17.595339
# std        48.740295       2.871913
# min         0.000000       0.000000
# 25%       211.000000      17.000000
# 50%       245.000000      17.000000
# 75%       282.000000      18.000000
# max       500.000000      74.000000

# %%
sns.boxplot(data=icfes2, x='ESTU_EDAD')

# %% [markdown]
# Se puede observar que existen observaciones con edades desde 0 años, ¿qué tratamiento le daría estas observaciones con edades sospechosamente bajas?

# %%
icfes.loc[icfes['ESTU_EDAD'] < 14]
# Out:
#        ESTU_GENERO ESTU_FECHANACIMIENTO ESTU_TIENEETNIA ESTU_DEPTO_RESIDE  \
# 1234             F           13/03/2013              No             VALLE
# 2082             F           05/08/2009              No             VALLE
# 2423             M           13/07/2020              No         ANTIOQUIA
# 2857             M           30/07/2007              No            BOGOTÁ
# 3139             M           03/09/2020              No            CALDAS
# 3804             F           21/06/2011              No            BOGOTÁ
# 5894             F           19/02/2013              Si             CAUCA
# 8380             M           05/01/2008              No         ATLANTICO
# 11406            F           22/06/2011              No            BOGOTÁ
# 12306            F           17/03/2020              No   NORTE SANTANDER
# 13564            F           03/05/2014              No            BOGOTÁ
# 16923            F           09/04/2009              No           BOLIVAR
# 19300            M           08/01/2013              No           BOLIVAR
# 19540            F           05/07/2007              No             VALLE
# 21893            F           11/03/2020              No      CUNDINAMARCA
# 22514            F           05/05/2020              No           BOLIVAR
# 28329            M           01/12/2013              No             SUCRE
# 31112            M           02/02/2014              No      CUNDINAMARCA
# 34851            F           30/03/2011              No         MAGDALENA
# 35813            M           05/02/2013              No            BOGOTÁ
# 36855            M           27/11/2008              No            BOGOTÁ
# 38458            F           01/12/2013              No            BOGOTÁ
# 39141            F           18/11/2010              No         ANTIOQUIA
# 40108            M           25/06/2020              Si            NARIÑO
# 41574            F           06/09/2020              No              META
# 43377            F           21/06/2020              No           BOLIVAR
# 46564            M           28/06/2020              No             HUILA
# 51163            F           20/10/2008              No         ATLANTICO
# 52255            M           08/07/2013              No            BOGOTÁ
# 52838            F           17/06/2020              No         SANTANDER
# 54525            F           19/02/2008              No             VALLE
# 55108            M           18/01/2011              No            CALDAS
# 59549            M           12/02/2012              No         ANTIOQUIA
# 61992            F           01/11/2008              No            TOLIMA
# 64899            M           18/02/2010             NaN            BOGOTÁ
# 65839            F           13/12/2012              No         ATLANTICO
# 66115            M           22/04/2020              No      CUNDINAMARCA
# 66429            F           02/09/2020              No         MAGDALENA
# 69047            M           10/09/2020              No      CUNDINAMARCA
# 74629            F           14/01/2014              No         SANTANDER
# 79673            F           26/04/2010              No           BOLIVAR
# 80281            F           23/09/2012              No           CORDOBA
# 80966            M           30/05/2008              No              META
# 81425            F           16/02/2012              No         ANTIOQUIA
# 81899            M           01/12/2012              No            TOLIMA
# 83663            M           07/02/2008              No             CESAR
# 86632            M           20/08/2020              No             SUCRE
# 86912            F           21/07/2015             NaN            BOGOTÁ
# 87270            F           07/12/2010              No             HUILA
# 90480            F           14/05/2010              No            BOGOTÁ
# 91297            M           06/11/2012              No            BOYACA
# 91847            F           30/10/2007              No             VALLE
# 92360            F           07/10/2007              No        LA GUAJIRA
# 92867            F           30/08/2008              No             HUILA
# 94583            M           02/05/2012              No             CESAR
# 94638            M           22/09/2011              No              META
# 98138            M           20/05/2010              No            CALDAS
# 99109            M           11/08/2013              No            BOYACA
# 100054           M           29/07/2020              No      CUNDINAMARCA
# 100068           M           07/08/2008              No      CUNDINAMARCA
#
#        FAMI_ESTRATOVIVIENDA                   FAMI_EDUCACIONPADRE  \
# 1234              Estrato 1                   Primaria incompleta
# 2082              Estrato 3  Secundaria (Bachillerato) incompleta
# 2423              Estrato 2                     Primaria completa
# 2857                    NaN                                   NaN
# 3139              Estrato 2                               Ninguno
# 3804              Estrato 3        Educación profesional completa
# 5894              Estrato 6    Secundaria (Bachillerato) completa
# 8380                    NaN                                   NaN
# 11406             Estrato 2                     Primaria completa
# 12306             Estrato 1                               Ninguno
# 13564             Estrato 3    Secundaria (Bachillerato) completa
# 16923             Estrato 3                             Postgrado
# 19300             Estrato 4                               No sabe
# 19540             Estrato 4                               No sabe
# 21893             Estrato 3        Educación profesional completa
# 22514             Estrato 1    Secundaria (Bachillerato) completa
# 28329             Estrato 2        Educación profesional completa
# 31112             Estrato 2    Secundaria (Bachillerato) completa
# 34851             Estrato 1                                   NaN
# 35813             Estrato 3      Educación profesional incompleta
# 36855             Estrato 2    Secundaria (Bachillerato) completa
# 38458             Estrato 2      Técnica o tecnológica incompleta
# 39141             Estrato 3      Técnica o tecnológica incompleta
# 40108           Sin Estrato                               No sabe
# 41574                   NaN                                   NaN
# 43377             Estrato 2    Secundaria (Bachillerato) completa
# 46564             Estrato 3                             Postgrado
# 51163             Estrato 3  Secundaria (Bachillerato) incompleta
# 52255             Estrato 4                               No sabe
# 52838             Estrato 2        Técnica o tecnológica completa
# 54525             Estrato 3    Secundaria (Bachillerato) completa
# 55108             Estrato 3        Educación profesional completa
# 59549             Estrato 3  Secundaria (Bachillerato) incompleta
# 61992             Estrato 1                     Primaria completa
# 64899             Estrato 3    Secundaria (Bachillerato) completa
# 65839             Estrato 1    Secundaria (Bachillerato) completa
# 66115             Estrato 1                   Primaria incompleta
# 66429             Estrato 1    Secundaria (Bachillerato) completa
# 69047             Estrato 2    Secundaria (Bachillerato) completa
# 74629             Estrato 2  Secundaria (Bachillerato) incompleta
# 79673             Estrato 1      Técnica o tecnológica incompleta
# 80281             Estrato 1    Secundaria (Bachillerato) completa
# 80966             Estrato 2    Secundaria (Bachillerato) completa
# 81425             Estrato 2    Secundaria (Bachillerato) completa
# 81899             Estrato 2                               Ninguno
# 83663             Estrato 4        Educación profesional completa
# 86632                   NaN                                   NaN
# 86912             Estrato 3        Educación profesional completa
# 87270             Estrato 4        Educación profesional completa
# 90480             Estrato 3                               No sabe
# 91297             Estrato 1  Secundaria (Bachillerato) incompleta
# 91847             Estrato 3    Secundaria (Bachillerato) completa
# 92360           Sin Estrato                   Primaria incompleta
# 92867             Estrato 3        Técnica o tecnológica completa
# 94583             Estrato 2    Secundaria (Bachillerato) completa
# 94638             Estrato 5                               Ninguno
# 98138             Estrato 3  Secundaria (Bachillerato) incompleta
# 99109             Estrato 2  Secundaria (Bachillerato) incompleta
# 100054            Estrato 2                   Primaria incompleta
# 100068            Estrato 2    Secundaria (Bachillerato) completa
#
#                          FAMI_EDUCACIONMADRE FAMI_TIENEINTERNET  \
# 1234                     Primaria incompleta                 Si
# 2082    Secundaria (Bachillerato) incompleta                 Si
# 2423    Secundaria (Bachillerato) incompleta                 Si
# 2857                                     NaN                NaN
# 3139                                 Ninguno                 No
# 3804        Educación profesional incompleta                 Si
# 5894                       Primaria completa                 No
# 8380                                     NaN                NaN
# 11406     Secundaria (Bachillerato) completa                 Si
# 12306                    Primaria incompleta                 Si
# 13564         Técnica o tecnológica completa                 Si
# 16923                              Postgrado                 Si
# 19300         Educación profesional completa                 Si
# 19540     Secundaria (Bachillerato) completa                 Si
# 21893       Educación profesional incompleta                 Si
# 22514         Técnica o tecnológica completa                 Si
# 28329     Secundaria (Bachillerato) completa                 Si
# 31112     Secundaria (Bachillerato) completa                 Si
# 34851                                    NaN                 Si
# 35813     Secundaria (Bachillerato) completa                 Si
# 36855     Secundaria (Bachillerato) completa                 Si
# 38458       Educación profesional incompleta                 Si
# 39141         Técnica o tecnológica completa                 Si
# 40108                                No sabe                 No
# 41574                                    NaN                NaN
# 43377     Secundaria (Bachillerato) completa                 Si
# 46564                              Postgrado                 Si
# 51163   Secundaria (Bachillerato) incompleta                 No
# 52255                                No sabe                 Si
# 52838   Secundaria (Bachillerato) incompleta                 Si
# 54525     Secundaria (Bachillerato) completa                 Si
# 55108         Educación profesional completa                 Si
# 59549         Técnica o tecnológica completa                 Si
# 61992         Técnica o tecnológica completa                 No
# 64899                    Primaria incompleta                 Si
# 65839     Secundaria (Bachillerato) completa                 Si
# 66115                    Primaria incompleta                 No
# 66429     Secundaria (Bachillerato) completa                 No
# 69047         Técnica o tecnológica completa                 No
# 74629   Secundaria (Bachillerato) incompleta                 Si
# 79673       Técnica o tecnológica incompleta                 Si
# 80281         Técnica o tecnológica completa                 Si
# 80966     Secundaria (Bachillerato) completa                 No
# 81425         Técnica o tecnológica completa                 Si
# 81899   Secundaria (Bachillerato) incompleta                 Si
# 83663         Educación profesional completa                 Si
# 86632                                    NaN                NaN
# 86912         Educación profesional completa                 Si
# 87270         Educación profesional completa                 Si
# 90480     Secundaria (Bachillerato) completa                 No
# 91297   Secundaria (Bachillerato) incompleta                 No
# 91847     Secundaria (Bachillerato) completa                 Si
# 92360     Secundaria (Bachillerato) completa                 No
# 92867         Educación profesional completa                 Si
# 94583   Secundaria (Bachillerato) incompleta                 No
# 94638                      Primaria completa                 No
# 98138   Secundaria (Bachillerato) incompleta                 Si
# 99109   Secundaria (Bachillerato) incompleta                 Si
# 100054                   Primaria incompleta                 Si
# 100068    Secundaria (Bachillerato) completa                 Si
#
#        FAMI_TIENECOMPUTADOR COLE_NATURALEZA COLE_AREA_UBICACION COLE_JORNADA  \
# 1234                     Si         OFICIAL              URBANO        UNICA
# 2082                     No         OFICIAL              URBANO       MAÑANA
# 2423                     No         OFICIAL              URBANO     SABATINA
# 2857                    NaN      NO OFICIAL              URBANO     SABATINA
# 3139                     No         OFICIAL              URBANO        NOCHE
# 3804                     Si         OFICIAL              URBANO        TARDE
# 5894                    NaN         OFICIAL               RURAL       MAÑANA
# 8380                    NaN      NO OFICIAL              URBANO     COMPLETA
# 11406                    Si         OFICIAL              URBANO       MAÑANA
# 12306                    No         OFICIAL               RURAL        UNICA
# 13564                    Si         OFICIAL              URBANO        TARDE
# 16923                    Si      NO OFICIAL              URBANO       MAÑANA
# 19300                    No      NO OFICIAL              URBANO       MAÑANA
# 19540                    Si         OFICIAL              URBANO        TARDE
# 21893                    Si         OFICIAL              URBANO       MAÑANA
# 22514                    No         OFICIAL              URBANO        TARDE
# 28329                    No      NO OFICIAL              URBANO       MAÑANA
# 31112                    Si      NO OFICIAL              URBANO     COMPLETA
# 34851                    No         OFICIAL              URBANO       MAÑANA
# 35813                    Si      NO OFICIAL              URBANO     COMPLETA
# 36855                    Si      NO OFICIAL              URBANO     COMPLETA
# 38458                    Si      NO OFICIAL              URBANO     COMPLETA
# 39141                    Si      NO OFICIAL              URBANO        TARDE
# 40108                    No         OFICIAL               RURAL       MAÑANA
# 41574                   NaN      NO OFICIAL              URBANO     SABATINA
# 43377                    Si         OFICIAL              URBANO        TARDE
# 46564                    No      NO OFICIAL              URBANO     COMPLETA
# 51163                    No         OFICIAL              URBANO        UNICA
# 52255                    Si      NO OFICIAL              URBANO     COMPLETA
# 52838                    No         OFICIAL              URBANO        UNICA
# 54525                    Si      NO OFICIAL              URBANO       MAÑANA
# 55108                    Si         OFICIAL              URBANO       MAÑANA
# 59549                    No         OFICIAL              URBANO        TARDE
# 61992                    Si         OFICIAL              URBANO        UNICA
# 64899                    Si      NO OFICIAL              URBANO       MAÑANA
# 65839                    No         OFICIAL              URBANO        TARDE
# 66115                    No      NO OFICIAL              URBANO       MAÑANA
# 66429                    No         OFICIAL              URBANO       MAÑANA
# 69047                    Si      NO OFICIAL              URBANO     COMPLETA
# 74629                    Si      NO OFICIAL              URBANO     COMPLETA
# 79673                    Si         OFICIAL              URBANO        TARDE
# 80281                    No         OFICIAL              URBANO       MAÑANA
# 80966                    No         OFICIAL              URBANO        UNICA
# 81425                    Si      NO OFICIAL              URBANO     COMPLETA
# 81899                    Si      NO OFICIAL              URBANO       MAÑANA
# 83663                    Si      NO OFICIAL              URBANO       MAÑANA
# 86632                   NaN      NO OFICIAL              URBANO     SABATINA
# 86912                    Si      NO OFICIAL              URBANO     COMPLETA
# 87270                    Si      NO OFICIAL              URBANO       MAÑANA
# 90480                    No         OFICIAL              URBANO        UNICA
# 91297                    Si      NO OFICIAL              URBANO       MAÑANA
# 91847                    Si      NO OFICIAL              URBANO       MAÑANA
# 92360                    Si         OFICIAL              URBANO        UNICA
# 92867                    No      NO OFICIAL              URBANO     COMPLETA
# 94583                    No         OFICIAL              URBANO        TARDE
# 94638                    No      NO OFICIAL              URBANO     SABATINA
# 98138                    No         OFICIAL               RURAL       MAÑANA
# 99109                    Si      NO OFICIAL              URBANO       MAÑANA
# 100054                   Si         OFICIAL              URBANO     SABATINA
# 100068                   No         OFICIAL               RURAL        UNICA
#
#         PUNT_GLOBAL                   ESTU_GENERACION-E  ESTU_EDAD
# 1234            235                                  NO          7
# 2082            253                                  NO         11
# 2423            216                                  NO          0
# 2857            208                                  NO         13
# 3139            246                                  NO          0
# 3804            253                                  NO          9
# 5894            205                                  NO          7
# 8380            292                                  NO         12
# 11406           238                                  NO          9
# 12306           233            GENERACION E - GRATUIDAD          0
# 13564           220            GENERACION E - GRATUIDAD          6
# 16923           342                                  NO         11
# 19300           268                                  NO          7
# 19540           212                                  NO         13
# 21893           303                                  NO          0
# 22514           219            GENERACION E - GRATUIDAD          0
# 28329           266            GENERACION E - GRATUIDAD          7
# 31112           288                                  NO          6
# 34851           172            GENERACION E - GRATUIDAD          9
# 35813           182                                  NO          7
# 36855           281                                  NO         12
# 38458           326                                  NO          7
# 39141           308                                  NO         10
# 40108           187            GENERACION E - GRATUIDAD          0
# 41574           248                                  NO          0
# 43377           290            GENERACION E - GRATUIDAD          0
# 46564           341                                  NO          0
# 51163           207            GENERACION E - GRATUIDAD         12
# 52255           310                                  NO          7
# 52838           293                                  NO          0
# 54525           232                                  NO         12
# 55108           240                                  NO          9
# 59549           296                                  NO          8
# 61992           215            GENERACION E - GRATUIDAD         12
# 64899           294                                  NO         10
# 65839           220            GENERACION E - GRATUIDAD          8
# 66115           225            GENERACION E - GRATUIDAD          0
# 66429           243                                  NO          0
# 69047           265                                  NO          0
# 74629           325                                  NO          6
# 79673           162            GENERACION E - GRATUIDAD         10
# 80281           232            GENERACION E - GRATUIDAD          8
# 80966           201            GENERACION E - GRATUIDAD         12
# 81425           243            GENERACION E - GRATUIDAD          8
# 81899           356  GENERACION E - EXCELENCIA NACIONAL          8
# 83663           205            GENERACION E - GRATUIDAD         12
# 86632           241            GENERACION E - GRATUIDAD          0
# 86912           292                                  NO          5
# 87270           213                                  NO         10
# 90480           252                                  NO         10
# 91297           274            GENERACION E - GRATUIDAD          8
# 91847           315                                  NO         13
# 92360           174            GENERACION E - GRATUIDAD         13
# 92867           265                                  NO         12
# 94583           171            GENERACION E - GRATUIDAD          8
# 94638           178            GENERACION E - GRATUIDAD          9
# 98138           237                                  NO         10
# 99109           307                                  NO          7
# 100054          200            GENERACION E - GRATUIDAD          0
# 100068          258                                  NO         12

# %% [markdown]
# ### Inspección y corrección de valores faltantes
#
# Para corregir los valores faltantes hay varias alternativas, a continuación también se mencionan las funciones de la librería pandas que se emplean en cada caso:
#
# * Eliminar los registros con NAs - `dropna()`
# * Reemplazar por un valor constante (la media, la mediana, la moda o un valor personalizado) - `fillna()`
# * Reemplazar por el último valor no faltante - `fillna()` esta solución es especialmente útil para series de tiempo, o conjuntos de datos altamente correlacionados.
# * Utilizar modelos predictivos para hacer la imputación de valores faltantes.
#
# Ahora debemos hacer un conteo de los valores faltantes por cada variable. Tenga presente que existen varios tipos de valores nulos: None, NaN y NA. NA es la representación más utilizada.

# %%
icfes2.shape
# Out:
# (100971, 15)

# %%
icfes2.isnull().sum()
# Out:
# ESTU_GENERO                2
# ESTU_FECHANACIMIENTO       0
# ESTU_TIENEETNIA            0
# ESTU_DEPTO_RESIDE          0
# FAMI_ESTRATOVIVIENDA    3398
# FAMI_EDUCACIONPADRE     2601
# FAMI_EDUCACIONMADRE     2707
# FAMI_TIENEINTERNET      2700
# FAMI_TIENECOMPUTADOR    4046
# COLE_NATURALEZA            0
# COLE_AREA_UBICACION        0
# COLE_JORNADA               0
# PUNT_GLOBAL                0
# ESTU_GENERACION-E          0
# ESTU_EDAD                  0
# dtype: int64

# %%
icfes2.isnull().sum()*100/ icfes2.shape[0]
# Out:
# ESTU_GENERO             0.001981
# ESTU_FECHANACIMIENTO    0.000000
# ESTU_TIENEETNIA         0.604134
# ESTU_DEPTO_RESIDE       0.000000
# FAMI_ESTRATOVIVIENDA    3.365323
# FAMI_EDUCACIONPADRE     2.575987
# FAMI_EDUCACIONMADRE     2.680968
# FAMI_TIENEINTERNET      2.674035
# FAMI_TIENECOMPUTADOR    4.007091
# COLE_NATURALEZA         0.000000
# COLE_AREA_UBICACION     0.000000
# COLE_JORNADA            0.000000
# PUNT_GLOBAL             0.000000
# ESTU_GENERACION-E       0.000000
# ESTU_EDAD               0.000000
# dtype: float64

# %% [markdown]
# La forma más sencilla para lidiar con los NAs es eliminándolos del dataset. En este caso pasamos de 100.971 observaciones a 94.912. Tan solo perdimos el 6% de los datos. Algunos modelos como el de regresión lineal `lm()` permiten lidiar con los NAs de varias formas, sin embargo en la gran mayoría de algoritmos hay que lidiar con esta situación antes del modelamiento.

# %%
# Con la opci´´on inplace = True puede modificar el dataset original

icfes_nona = icfes2.dropna()

print(icfes_nona.isnull().sum())
print(icfes2.shape)
print(icfes_nona.shape)
# Out:
# ESTU_GENERO             0
# ESTU_FECHANACIMIENTO    0
# ESTU_TIENEETNIA         0
# ESTU_DEPTO_RESIDE       0
# FAMI_ESTRATOVIVIENDA    0
# FAMI_EDUCACIONPADRE     0
# FAMI_EDUCACIONMADRE     0
# FAMI_TIENEINTERNET      0
# FAMI_TIENECOMPUTADOR    0
# COLE_NATURALEZA         0
# COLE_AREA_UBICACION     0
# COLE_JORNADA            0
# PUNT_GLOBAL             0
# ESTU_GENERACION-E       0
# ESTU_EDAD               0
# dtype: int64
# (100971, 15)
# (94912, 15)

# %% [markdown]
# Es conveniente contar cuantos NAs existen en una observación determinada, por ejemplo hay 3269 observaciones con 1 solo valor faltante, observaciones con múltiples valores faltantes son dificilmente rescatables ya que hay demasiada información que recuperar. Estos casos pueden ser imputados utilizando modelos predictivos

# %%
icfes2[icfes2.isnull().sum(axis = 1) ==5].count()
# Out:
# ESTU_GENERO             2335
# ESTU_FECHANACIMIENTO    2335
# ESTU_TIENEETNIA         2335
# ESTU_DEPTO_RESIDE       2335
# FAMI_ESTRATOVIVIENDA       0
# FAMI_EDUCACIONPADRE        0
# FAMI_EDUCACIONMADRE        0
# FAMI_TIENEINTERNET         0
# FAMI_TIENECOMPUTADOR       0
# COLE_NATURALEZA         2335
# COLE_AREA_UBICACION     2335
# COLE_JORNADA            2335
# PUNT_GLOBAL             2335
# ESTU_GENERACION-E       2335
# ESTU_EDAD               2335
# dtype: int64

# %% [markdown]
# En algunos casos se puede reemplazar los NAs por la mediana o media en el caso de variables cuantitativas, o por la moda en el caso de variables cualitativas, a continuacón vamos a reemplazar los valores faltantes de la variable `ESTU_TIENEETNIA` por la moda que es "No".

# %%
icfes2['ESTU_TIENEETNIA'].value_counts(normalize = True)
# Out:
# No    0.936903
# Si    0.063097
# Name: ESTU_TIENEETNIA, dtype: float64

# %%
icfes2['ESTU_TIENEETNIA'] = icfes2['ESTU_TIENEETNIA'].fillna(value = 'No')

# Se cuentan la cantidad de valores nulos en la variable ESTU_TIENEETINA

icfes2['ESTU_TIENEETNIA'].isnull().sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0

# %% [markdown]
# ## **4. Dataset air london**

# %%
air.describe()
# Out:
#               Value
# count  32136.000000
# mean      15.596621
# std       10.442254
# min       -3.000000
# 25%        9.000000
# 50%       13.000000
# 75%       18.000000
# max      194.000000

# %% [markdown]
# En el resumen se puede observar que todas las mediciones fueron realizadas en el mismo sitio, solo hay una especie medida que es PM2.5, la unidad es la misma en todos los casos y las mediciones ratificadas. Las únicas variables útiles son `ReadingDateTime` y `Value`. En el caso de `Value` se observa que tiene 2904 NAs, a continuación se muestra como hacer el reemplazo por la mediana usando `replace_na` y `fill`. Al tratarse de una serie de tiempo, la opción de llenado con `fill` es la más indicada.

# %% [markdown]
# ### Reemplazo con la mediana

# %%
air.isnull().sum()
# Out:
# Site                          0
# Species                       0
# ReadingDateTime               0
# Value                      2904
# Units                         0
# Provisional or Ratified       0
# dtype: int64

# %%
air.isnull().sum()*100/air.shape[0]
# Out:
# Site                       0.000000
# Species                    0.000000
# ReadingDateTime            0.000000
# Value                      8.287671
# Units                      0.000000
# Provisional or Ratified    0.000000
# dtype: float64

# %%
# Se crea una copia del dataset
air_median = air

air_median['Value'].median()
# Out:
# 13.0

# %%
# Este método solo se aplicará sobre variables numéricas
air_median = air.fillna(13)

air_median.isnull().sum()
# Out:
# Site                       0
# Species                    0
# ReadingDateTime            0
# Value                      0
# Units                      0
# Provisional or Ratified    0
# dtype: int64

# %% [markdown]
# ### Reemplazo con `fillna`

# %% [markdown]
# Se pueden reemplazar los valores faltantes con las entradas previas o siguientes. Para más información de la función `fillna` consulte [aquí](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html).

# %%
# con inplace=True se cambiar permanentemente el dataset
# el método ffill -forward fill- propaga la última observación válida para hacer el reemplazo
air.fillna(method='ffill', inplace=True)

air.isnull().sum()
# Out:
# Site                       0
# Species                    0
# ReadingDateTime            0
# Value                      0
# Units                      0
# Provisional or Ratified    0
# dtype: int64

# %% [markdown]
# **Créditos**
# ---
#
# **Profesor:** Harry Vargas Rodríguez
#
# **Corporación Universitaria de Cataluña** - *Diplomado en Big Data y Data Science*
